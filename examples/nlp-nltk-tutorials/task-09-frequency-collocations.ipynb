# %% [markdown]
# # Task 09: Frequency Analysis and Collocations
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vuhung16au/nlp-learning-journey/blob/main/examples/nlp-nltk-tutorials/task-09-frequency-collocations.ipynb)
#
# ## Overview
#
# Frequency analysis helps identify common and rare words, while collocations are words that frequently appear together. This tutorial covers statistical measures and techniques for finding meaningful patterns in text.
#
# ## What You'll Learn
#
# - Word frequency distribution
# - Frequency plots and visualization
# - Finding collocations and bigrams
# - Pointwise Mutual Information (PMI)
# - Chi-square test for collocations
# - N-gram analysis

# %% [markdown]
# ## Environment Setup

# %%
# Environment Detection and Setup
import sys
import subprocess
import os

# Detect the runtime environment
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules
IS_LOCAL = not (IS_COLAB or IS_KAGGLE)

print(f"Environment detected:")
print(f"  - Local: {IS_LOCAL}")
print(f"  - Google Colab: {IS_COLAB}")
print(f"  - Kaggle: {IS_KAGGLE}")

# Install required packages
required_packages = ["nltk"]

print("\nInstalling required packages...")
for package in required_packages:
    if IS_COLAB or IS_KAGGLE:
        # !pip install -q {package}
    else:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", package], 
                      capture_output=True)
    print(f"✓ {package}")

# %% [markdown]
# ## Import Libraries

# %%
import nltk

# Download required NLTK data
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('maxent_ne_chunker', quiet=True)
nltk.download('words', quiet=True)

print("Libraries imported successfully!")

# %% [markdown]
# ## Content for Frequency Analysis and Collocations
#
# This tutorial covers practical examples and exercises for understanding and implementing {data['title'].lower()} using NLTK.
#
# ### Key Concepts
#
# Throughout this notebook, we'll explore:
# - Fundamental concepts and theory
# - Practical code examples with English and Vietnamese text
# - Comparative analysis of different approaches
# - Real-world applications and use cases
# - Performance considerations
#
# ### Vietnamese/English Examples
#
# Following the repository's focus on Vietnamese/English language pairs, we'll use parallel examples:
# - English: "My name is" → Vietnamese: "Tên tôi là"
# - English: "Hello" → Vietnamese: "Xin chào"
# - English: "Thank you" → Vietnamese: "Cảm ơn"

# %% [markdown]
# ## Example 1: Basic Implementation

# %%
# English example
english_text = "My name is John. I love Natural Language Processing!"
print(f"English: {english_text}")

# Vietnamese example
vietnamese_text = "Tên tôi là John. Tôi yêu xử lý ngôn ngữ tự nhiên!"
print(f"Vietnamese: {vietnamese_text}")

# TODO: Add specific implementation for this task

# %% [markdown]
# ## Key Takeaways
#
# 1. **Core Concept**: Understanding the fundamentals is essential for effective application
# 2. **Language Differences**: Vietnamese and English may require different approaches
# 3. **Best Practices**: Follow established patterns for optimal results
# 4. **Performance**: Consider computational efficiency for large-scale applications
# 5. **Context Matters**: Choose appropriate techniques based on your specific use case
#
# ## Next Steps
#
# - Continue to the next tutorial in the series
# - Practice with your own text data
# - Explore advanced techniques and optimizations
# - Apply these concepts to real-world NLP projects
#
# ## Additional Resources
#
# - [NLTK Documentation](https://www.nltk.org/)
# - [NLTK Book](https://www.nltk.org/book/)
# - [Natural Language Processing with Python](https://www.nltk.org/book/)
